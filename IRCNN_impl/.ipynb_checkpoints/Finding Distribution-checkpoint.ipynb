# %% [markdown]
# ## Define basic functions and import packages

# %%
import numpy as np
from matplotlib import pyplot as plt
import scipy.stats as st
import statsmodels as sm
import pandas as pd
import matplotlib
import warnings
from astropy.io.fits import getdata

matplotlib.style.use('ggplot')

# %%
# From https://stackoverflow.com/a/37616966/2713263
def best_fit_distribution(data, distributions, bins=200, ax=None):
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Distributions to check
    DISTRIBUTIONS = [        
        st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
        st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
        st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
        st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
        st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
        st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
        st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
        st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
        st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
        st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy
    ]

    # Best holders
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf

    # Estimate distribution parameters from data
    for distribution in distributions:
        print('Currently trying ' + distribution.name, end=', ')
        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax)
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse
                
                print('Current best: ' + best_distribution.name)
        except Exception:
            pass

    return (best_distribution.name, best_params)

# %%
def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf

# %% [markdown]
# ### Get stats about data

# %%
data = getdata('M13V20120711.fits')

# %%
data = data.byteswap().newbyteorder()

# %%
pd.DataFrame(data).describe()
# Out:
#               0           1           2           3           4           5    \
# count  951.000000  951.000000  951.000000  951.000000  951.000000  951.000000
# mean   122.453979  121.873024  122.540054  122.307701  123.357582  123.330376
# std     55.604843   45.423607   39.310261   37.718567   39.648705   41.323601
# min     71.757812   60.211075   52.451576   67.678131   66.809387   67.517044
# 25%     97.517254   96.549862   97.977379   95.884357   96.919228   96.540787
# 50%    112.671120  113.552315  112.632843  113.368118  113.243576  113.295959
# 75%    133.682617  132.584259  136.853180  139.047112  141.084038  139.417435
# max    809.121460  644.473389  450.188873  380.024353  445.092346  452.942444
#
#               6           7           8           9       ...      \
# count  951.000000  951.000000  951.000000  951.000000     ...
# mean   122.650383  122.498276  122.509026  123.884399     ...
# std     41.971336   42.113480   46.588215   56.550930     ...
# min     67.968063   65.745590   65.861504   64.668480     ...
# 25%     95.695534   94.872902   93.731434   94.822502     ...
# 50%    112.102982  112.488892  110.941780  109.800308     ...
# 75%    137.110260  135.420212  135.434174  133.198822     ...
# max    454.701019  392.532959  517.497742  693.496582     ...
#
#                941          942          943          944          945  \
# count   951.000000   951.000000   951.000000   951.000000   951.000000
# mean    154.818222   151.104828   147.463165   142.189163   137.737152
# std     118.610229   126.676575   127.937485   115.069427    93.994171
# min      64.671875    64.632484    56.850464    60.769722    63.951317
# 25%     102.771484   102.362911   100.328911    99.970207    99.844383
# 50%     124.218124   123.898849   121.034760   118.000427   118.464645
# 75%     155.664024   150.951332   150.046837   147.605164   147.940384
# max    1467.891602  1733.467651  1845.426147  1627.148560  1295.294678
#
#               946         947         948         949         950
# count  951.000000  951.000000  951.000000  951.000000  951.000000
# mean   133.652130  131.423553  130.194717  128.835312  127.936508
# std     74.700714   62.233871   58.679302   59.980263   59.490093
# min     62.181000   62.694397   63.280491   58.596542   56.998848
# 25%     99.671539   99.378746  100.287079   98.446732   98.979309
# 50%    117.441437  116.793442  118.061394  115.961380  115.240402
# 75%    145.165154  142.069115  141.365982  140.667007  141.944107
# max    945.331787  640.248840  594.087646  721.801086  697.477051
#
# [8 rows x 951 columns]

# %%
pd.DataFrame(data.ravel()).describe()
# Out:
#                    0
# count  904401.000000
# mean      400.864868
# std       737.239685
# min        52.451576
# 25%       140.069305
# 50%       209.082565
# 75%       397.176208
# max     29325.070312

# %%
len(np.unique(data))
# Out:
# 885752

# %% [markdown]
# ## Get best fit distribution

# %%
data = pd.Series(data.ravel())

# %%
plt.figure(figsize=(12,8))
ax = data.plot(kind='hist', bins=50, density=True, alpha=0.5)
# Save plot limits
dataYLim = ax.get_ylim()

# %%
# Find best fit distribution
distributions = [st.weibull_min, st.laplace, st.expon, st.exponnorm, st.exponweib, st.cauchy, 
                st.dgamma, st.gamma, st.weibull_max, st.lognorm, st.chi2, st.pareto, st.rayleigh]
best_fit_name, best_fit_paramms = best_fit_distribution(data, distributions, 200, ax)
best_dist = getattr(st, best_fit_name)

# %%
# Update plots
ax.set_ylim(dataYLim)
ax.set_ylabel('Frequency')
# Out:
# Text(20.2,0.5,'Frequency')

# %%
pdf = make_pdf(best_dist, best_fit_paramms)

# %%
# Display
plt.figure(figsize=(12,8))
ax = pdf.plot(lw=2, label='PDF', legend=True)
data.plot(kind='hist', bins=50, density=True, alpha=0.5, label='Data', legend=True, ax=ax)

# %%
param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_paramms)])
dist_str = '{}({})'.format(best_fit_name, param_str)
print(dist_str)
# Out:
# lognorm(s=0.91, loc=52.44, scale=187.39)

# %% [markdown]
# ## Best-fit distribution for reference image

# %%
ref = getdata('M13Vreferencefr.fits')
plt.imshow(ref, cmap='gray')

# %%
ref = ref.byteswap().newbyteorder()
ref = pd.Series(ref.ravel())

# %%
sub = data - ref

# %%
plt.figure(figsize=(12,8))
ax = sub.plot(kind='hist', bins=50, density=True, alpha=0.5)
# Save plot limits
subYLim = ax.get_ylim()

# %%
best_fit_name, best_fit_paramms = best_fit_distribution(sub, distributions, 200, ax)
best_dist = getattr(st, best_fit_name)

# Update plots
ax.set_ylim(subYLim);
ax.set_ylabel('Frequency');

pdf = make_pdf(best_dist, best_fit_paramms)

# Display
plt.figure(figsize=(12,8))
ax = pdf.plot(lw=2, label='PDF', legend=True);
sub.plot(kind='hist', bins=50, density=True, alpha=0.5, label='Data', legend=True, ax=ax);
# Out:
# Currently trying  weibull_min
# Currently trying  laplace
# Currently trying  expon
# Currently trying  exponnorm
# Currently trying  exponweib
# Currently trying  cauchy
# Currently trying  dgamma
# Currently trying  gamma
# Currently trying  weibull_max
# Currently trying  lognorm
# Currently trying  chi2
# Currently trying  pareto

# %%
param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_paramms)])
dist_str = '{}({})'.format(best_fit_name, param_str)
print(dist_str)
# Out:
# dgamma(a=0.52, loc=17.33, scale=86.46)

# %% [markdown]
# ## Using PNG

# %%
data.plot(kind='hist')

# %%
from PIL import Image

data = getdata('M13V20120711.fits')
file = Image.fromarray(data)
file = file.convert('L')  # black and white
file.save('test.png')

# %%
png_data = Image.open('test.png')
png_data = np.array(png_data)

# %%
png_data.shape
# Out:
# (951, 951)

# %%
plt.imshow(png_data, cmap='gray')

# %%
plt.hist(png_data.ravel())
# Out:
# (array([  1035.,  24378.,  74007.,  99024.,  86848.,  70679.,  61434.,
#          48314.,  39717., 398965.]),
#  array([ 52. ,  72.3,  92.6, 112.9, 133.2, 153.5, 173.8, 194.1, 214.4,
#         234.7, 255. ]),
#  <a list of 10 Patch objects>)

# %%
series = pd.Series(png_data.ravel())

# %%
best_fit_name, best_fit_paramms = best_fit_distribution(series, distributions, 200, ax)
best_dist = getattr(st, best_fit_name)

pdf = make_pdf(best_dist, best_fit_paramms)

# Display
plt.figure(figsize=(12,8))
ax = pdf.plot(lw=2, label='PDF', legend=True);
series.plot(kind='hist', bins=50, density=True, alpha=0.5, label='Data', legend=True, ax=ax);
# Out:
# Currently trying weibull_min, Current best: weibull_min
# Currently trying laplace, Current best: weibull_min
# Currently trying expon, Current best: weibull_min
# Currently trying exponnorm, Current best: exponnorm
# Currently trying exponweib, Current best: exponnorm
# Currently trying cauchy, Current best: exponnorm
# Currently trying dgamma, Current best: dgamma
# Currently trying gamma, Current best: dgamma
# Currently trying weibull_max, Current best: weibull_max
# Currently trying lognorm, Current best: weibull_max
# Currently trying chi2, Current best: weibull_max
# Currently trying pareto, Current best: weibull_max

# %%
param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_paramms)])
dist_str = '{}({})'.format(best_fit_name, param_str)
print(dist_str)
# Out:
# weibull_max(c=0.92, loc=255.00, scale=63.77)

# %%
ax = pdf.plot(lw=2, label='PDF', legend=True);
series.plot(kind='hist', alpha=0.5, label='Data', density=True, legend=True, ax=ax);

# %%
ref = getdata('M13Vreferencefr.fits')
file = Image.fromarray(ref)
file = file.convert('L')  # black and white
file.save('test.png')

png_data = Image.open('test.png')
png_data = np.array(png_data)
plt.imshow(png_data, cmap='gray')

# %%
plt.hist(png_data.ravel())
# Out:
# (array([ 10145.,  68154.,  96459.,  90755.,  71928.,  61060.,  51134.,
#          42688.,  35712., 376366.]),
#  array([ 47. ,  67.8,  88.6, 109.4, 130.2, 151. , 171.8, 192.6, 213.4,
#         234.2, 255. ]),
#  <a list of 10 Patch objects>)

# %%
series2 = pd.Series(png_data.ravel())

# %%
sub = series - series2

# %%
plt.hist(sub)
# Out:
# (array([6.84490e+05, 1.46602e+05, 6.92000e+03, 1.46000e+02, 1.10000e+01,
#         6.00000e+00, 1.00000e+01, 2.04000e+02, 4.68800e+03, 6.13240e+04]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
best_fit_name, best_fit_paramms = best_fit_distribution(sub, [st.rayleigh, st.weibull_min], 200)
best_dist = getattr(st, best_fit_name)

pdf = make_pdf(best_dist, best_fit_paramms)

# Display
plt.figure(figsize=(12,8))
ax = pdf.plot(lw=2, label='PDF', legend=True);
sub.plot(kind='hist', density=True, alpha=0.5, label='Data', legend=True, ax=ax);
# Out:
# Currently trying rayleigh, Current best: rayleigh
# Currently trying weibull_min, Current best: weibull_min

# %% [markdown]
# ## Comparing Rayleigh and Weibull Min distributions for subtracted image

# %%
y, x = np.histogram(sub, bins=10, density=True)
x = (x + np.roll(x, -1))[:-1] / 2.0

params = st.weibull_min.fit(sub)
#arg = params[:-2]
#loc = params[-2]
#scale = params[-1]
#pdf = st.weibull_min.pdf(x, loc=loc, scale=scale, *arg)
#sse = np.sum(np.power(y - pdf, 2.0))

# %%
print('weibull_min sse = ', sse)
# Out:
# weibull_min sse =  0.00031228911137982674

# %%
pdf = make_pdf(st.rayleigh, params)

plt.figure(figsize=(12,8))
plt.title('Weibull Min')
ax = pdf.plot(lw=2, label='PDF', legend=True);
sub.plot(kind='hist', density=True, alpha=0.5, label='Data', legend=True, ax=ax);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-18780fc028b9> in <module>()
# ----> 1 pdf = make_pdf(st.rayleigh, params)
#       2
#       3 plt.figure(figsize=(12,8))
#       4 plt.title('Weibull Min')
#       5 ax = pdf.plot(lw=2, label='PDF', legend=True);
#
# <ipython-input-3-49a9a6336174> in make_pdf(dist, params, size)
#       8
#       9     # Get sane start and end points of distribution
# ---> 10     start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
#      11     end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)
#      12
#
# /usr/local/lib64/python3.6/site-packages/scipy/stats/_distn_infrastructure.py in ppf(self, q, *args, **kwds)
#    1898
#    1899         """
# -> 1900         args, loc, scale = self._parse_args(*args, **kwds)
#    1901         q, loc, scale = map(asarray, (q, loc, scale))
#    1902         args = tuple(map(asarray, args))
#
# TypeError: _parse_args() got multiple values for argument 'loc'

# %%
params = st.rayleigh.fit(sub)
arg = params[:-2]
loc = params[-2]
scale = params[-1]
pdf = st.rayleigh.pdf(x, loc=loc, scale=scale, *arg)
sse = np.sum(np.power(y - pdf, 2.0))

# %%
print('rayleigh sse = ', sse)
# Out:
# rayleigh sse =  0.0005222893584897027

# %%
pdf = make_pdf(st.rayleigh, params)

plt.figure(figsize=(12,8))
plt.title('Rayleigh')
ax = pdf.plot(lw=2, label='PDF', legend=True);
sub.plot(kind='hist', density=True, alpha=0.5, label='Data', legend=True, ax=ax);
